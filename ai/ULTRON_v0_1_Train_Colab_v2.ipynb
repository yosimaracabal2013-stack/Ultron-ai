# %% [markdown]
# # ULTRON v0.1 — Colab Training
#
# This notebook trains ULTRON's from-scratch Transformer and verifies the checkpoint before downloading it.

# %%
# %cd /content
# !rm -rf /content/Ultron-ai
# !git clone -q https://github.com/yosimaracabal2013-stack/Ultron-ai.git /content/Ultron-ai
# %cd /content/Ultron-ai
# !git checkout -q ultron-brain-v0.1
# !pwd
# !ls -la ai

# %%
# !pip -q install -r ai/requirements.txt
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %%
# !python ai/train.py
from pathlib import Path
checkpoint = Path('/content/Ultron-ai/ai/checkpoints/ultron_v0_1.pt')
if not checkpoint.exists():
    raise FileNotFoundError('Training did not create the ULTRON checkpoint: ' + str(checkpoint))
print('CHECKPOINT READY:', checkpoint)

# %%
# !python ai/generate.py --prompt 'ULTRON:' --tokens 300

# %%
prompt = 'USER: What is your purpose?\nULTRON:'
# !python ai/generate.py --prompt "$prompt" --tokens 200

# %%
from google.colab import files
from pathlib import Path
checkpoint = Path('/content/Ultron-ai/ai/checkpoints/ultron_v0_1.pt')
if not checkpoint.exists():
    raise FileNotFoundError('Checkpoint is missing. Run the training cell first.')
print(f'Downloading {checkpoint} ({checkpoint.stat().st_size:,} bytes)')
files.download(str(checkpoint))
