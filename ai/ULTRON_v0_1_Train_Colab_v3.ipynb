# %% [markdown]
# # ULTRON v0.1 — One-click Colab training
#
# This version avoids Git checkout and working-directory problems. It downloads the exact ULTRON v0.1 files directly from the public branch, trains, tests, and downloads the checkpoint.

# %%
# %cd /content
# !rm -rf /content/ultron_run
# !mkdir -p /content/ultron_run/ai/data
# !wget -q -O /content/ultron_run/ai/train.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/train.py
# !wget -q -O /content/ultron_run/ai/model.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/model.py
# !wget -q -O /content/ultron_run/ai/tokenizer.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/tokenizer.py
# !wget -q -O /content/ultron_run/ai/generate.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/generate.py
# !wget -q -O /content/ultron_run/ai/requirements.txt https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/requirements.txt
# !wget -q -O /content/ultron_run/ai/data/train.txt https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/data/train.txt
# !ls -la /content/ultron_run/ai
# !wc -c /content/ultron_run/ai/data/train.txt

# %%
# !pip -q install -r /content/ultron_run/ai/requirements.txt
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %%
# !python /content/ultron_run/ai/train.py
from pathlib import Path
checkpoint = Path('/content/ultron_run/ai/checkpoints/ultron_v0_1.pt')
if not checkpoint.exists():
    raise FileNotFoundError('Training did not create the checkpoint: ' + str(checkpoint))
print('CHECKPOINT READY:', checkpoint)
print('SIZE:', checkpoint.stat().st_size, 'bytes')

# %%
# !python /content/ultron_run/ai/generate.py --prompt 'ULTRON:' --tokens 200

# %%
from google.colab import files
from pathlib import Path
checkpoint = Path('/content/ultron_run/ai/checkpoints/ultron_v0_1.pt')
files.download(str(checkpoint))
