# %% [markdown]
# # ULTRON v0.2 — Expanded training
#
# This run trains a larger model on the expanded ULTRON dataset. GPU runtimes train for 1000 steps; CPU runtimes automatically use 300 steps so the test remains practical.
#
# **Run every cell from top to bottom. Do not stop the training cell unless you intentionally want to discard the current run. Checkpoints are saved every 100 steps.**

# %%
# %cd /content
# !rm -rf /content/ultron_v02_run
# !mkdir -p /content/ultron_v02_run/ai/data
# !wget -q -O /content/ultron_v02_run/ai/train_v0_2.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/train_v0_2.py
# !wget -q -O /content/ultron_v02_run/ai/generate_v0_2.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/generate_v0_2.py
# !wget -q -O /content/ultron_v02_run/ai/model.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/model.py
# !wget -q -O /content/ultron_v02_run/ai/tokenizer.py https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/tokenizer.py
# !wget -q -O /content/ultron_v02_run/ai/data/train.txt https://raw.githubusercontent.com/yosimaracabal2013-stack/Ultron-ai/ultron-brain-v0.1/ai/data/train.txt
# !wc -c /content/ultron_v02_run/ai/data/train.txt

# %%
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')
print('ULTRON v0.2: 4 layers, 128 hidden, 128 context')
print('Steps: 1000 on GPU, 300 on CPU')

# %%
# !python -u /content/ultron_v02_run/ai/train_v0_2.py
from pathlib import Path
checkpoint = Path('/content/ultron_v02_run/ai/checkpoints/ultron_v0_2.pt')
if not checkpoint.exists():
    raise FileNotFoundError('Training did not create the v0.2 checkpoint: ' + str(checkpoint))
print('CHECKPOINT READY:', checkpoint)
print('SIZE:', checkpoint.stat().st_size, 'bytes')

# %%
# !python -u /content/ultron_v02_run/ai/generate_v0_2.py --prompt 'ULTRON:' --tokens 200

# %%
from google.colab import files
from pathlib import Path
checkpoint = Path('/content/ultron_v02_run/ai/checkpoints/ultron_v0_2.pt')
files.download(str(checkpoint))
